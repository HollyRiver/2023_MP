# %% [markdown]
# ---
# title: "`Autogluon`과 여러가지 유형의 데이터"
# author: "강신성"
# date: "2023-12-02"
# categories: [autogluon]
# ---

# %% [markdown]
# > `autogluon`을 이용하여 다양한 유형의 데이터들을 적합해보자!

# %% [markdown]
# ## 1. 라이브러리 imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
#---#
import sklearn.model_selection
from autogluon.tabular import TabularPredictor
#pip install autogluon.eda
import autogluon.eda.auto as auto
#---#
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. 결측치와 타입별 교호작용이 있는 데이터

# %% [markdown]
# ### **A. 데이터 EDA**
# ---

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/guebin/MP2023/master/posts/mid/height_train.csv')
df_test = pd.read_csv('https://raw.githubusercontent.com/guebin/MP2023/master/posts/mid/height_test.csv')

# %%
df_train.head()
# Out:
#       weight     sex      height
# 0  71.169041    male  180.906857
# 1  69.204748    male  178.123281
# 2  49.037293  female  165.106085
# 3  74.472874    male  177.467439
# 4  74.239599    male  177.439925

# %%
sns.scatterplot(df_train, x = 'weight', y = 'height', hue = 'sex')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %% [markdown]
# * 성별 간 교호작용 존재
# * 결측치 존재(성별 별로 결측치 처리)

# %% [markdown]
# ### **B. 적합**
# ---

# %%
## step 1 -- pass(!)
## step 2 : create predictor
predictr = TabularPredictor(label = 'height')
## step 3 : fitting
predictr.fit(df_train)
## step 4 : prediction
yhat = predictr.predict(df_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231204_131536"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231204_131536"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #140-Ubuntu SMP Thu Aug 4 02:23:37 UTC 2022
# CPU Count:          128
# Memory Avail:       495.53 GB / 503.74 GB (98.4%)
# Disk Space Avail:   1421.51 GB / 1757.88 GB (80.9%)
# ===================================================
# Train Data Rows:    280
# Train Data Columns: 2
# Label Column:       height
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (195.79716947992372, 148.97529810482766, 174.60543, 9.4301)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    507421.87 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['weight']
# 		('object', []) : 1 | ['sex']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 1 | ['weight']
# 		('int', ['bool']) : 1 | ['sex']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.03s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 224, Val Rows: 56
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-3.463	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-3.3929	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 3.05149
# 	-3.0349	 = Validation score   (-root_mean_squared_error)
# 	2.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-3.1331	 = Validation score   (-root_mean_squared_error)
# 	0.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-3.0811	 = Validation score   (-root_mean_squared_error)
# 	0.41s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-2.8341	 = Validation score   (-root_mean_squared_error)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-3.0481	 = Validation score   (-root_mean_squared_error)
# 	0.42s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-3.0808	 = Validation score   (-root_mean_squared_error)
# 	3.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-3.0563	 = Validation score   (-root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-2.8592	 = Validation score   (-root_mean_squared_error)
# 	2.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-3.1759	 = Validation score   (-root_mean_squared_error)
# 	2.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'NeuralNetTorch': 0.408, 'CatBoost': 0.324, 'XGBoost': 0.183, 'KNeighborsUnif': 0.056, 'NeuralNetFastAI': 0.028}
# 	-2.7259	 = Validation score   (-root_mean_squared_error)
# 	0.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 13.86s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231204_131536")

# %%
sns.scatterplot(df_train, x = 'weight', y = 'height', hue = 'sex', alpha = 0.3)
sns.lineplot(df_train, x = 'weight', y = yhat, hue = 'sex')
plt.show()

# %% [markdown]
# > 별다른 처리작업 없이도 나름 잘 적합한다.

# %%
predictr.leaderboard(silent = True)
# Out:
#                   model  score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2  -2.725899  root_mean_squared_error       0.054086
# 1              CatBoost  -2.834127  root_mean_squared_error       0.001242
# 2        NeuralNetTorch  -2.859244  root_mean_squared_error       0.003218
# 3            LightGBMXT  -3.034869  root_mean_squared_error       0.001480
# 4         ExtraTreesMSE  -3.048093  root_mean_squared_error       0.041520
# 5               XGBoost  -3.056270  root_mean_squared_error       0.002266
# 6       NeuralNetFastAI  -3.080800  root_mean_squared_error       0.009215
# 7       RandomForestMSE  -3.081138  root_mean_squared_error       0.041080
# 8              LightGBM  -3.133082  root_mean_squared_error       0.000853
# 9         LightGBMLarge  -3.175914  root_mean_squared_error       0.001354
# 10       KNeighborsDist  -3.392890  root_mean_squared_error       0.026912
# 11       KNeighborsUnif  -3.463039  root_mean_squared_error       0.037876
#
#     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   7.245067                0.000268           0.197810            2
# 1   0.670497                0.001242           0.670497            1
# 2   2.448419                0.003218           2.448419            1
# 3   2.234592                0.001480           2.234592            1
# 4   0.416761                0.041520           0.416761            1
# 5   0.353590                0.002266           0.353590            1
# 6   3.569992                0.009215           3.569992            1
# 7   0.406985                0.041080           0.406985            1
# 8   0.875577                0.000853           0.875577            1
# 9   2.381327                0.001354           2.381327            1
# 10  0.004633                0.026912           0.004633            1
# 11  0.004760                0.037876           0.004760            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True          6
# 2        True         10
# 3        True          3
# 4        True          7
# 5        True          9
# 6        True          8
# 7        True          5
# 8        True          4
# 9        True         11
# 10       True          2
# 11       True          1

# %% [markdown]
# > `WeightEnsemble_L2`라는 모델로 적합한 것을 알 수 있습니당...

# %% [markdown]
# ### **C. 해석 및 시각화**
# ---

# %% [markdown]
# `-` 반응변수에 대한 분석(교수님은 비추)

# %%
auto.target_analysis(
    train_data = df_train,
    label = 'height',
    fit_distributions = False  ## 반응변수의 값들에 대한 분포가 어느 것에 가까운지를 추측하여 내놓는다. 효용이 적다
)
# Out:
# ## Target variable analysis
#         count        mean       std         min         25%         50%  \
# height    280  174.605431  9.430102  148.975298  167.572671  175.186487
#
#                75%         max   dtypes  unique missing_count missing_ratio  \
# height  181.132612  195.797169  float64     280
#
#        raw_type special_types
# height    float
# ### Target variable correlations
# **`train_data` - `spearman` correlation matrix; focus: absolute correlation for `height` >= `0.5`**
# **Feature interaction between `weight`/`height` in `train_data`**
# **Feature interaction between `sex`/`height` in `train_data`**

# %% [markdown]
# > 반응변수(target)의 분포, 상관성이 높은 설명변수(features) 요약이 포함되어 있다. 상관계수의 절댓값이 0.5 이상인 열만 산출하기에, 차라리 직접 EDA하는 것이 더 좋을 수 있다.

# %%
(pd.get_dummies(df_train, drop_first = True)*1).corr()
# Out:
#             weight    height  sex_male
# weight    1.000000  0.936472  0.877617
# height    0.936472  1.000000  0.753563
# sex_male  0.877617  0.753563  1.000000

# %%
sns.heatmap((pd.get_dummies(df_train, drop_first = True)*1).corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# > 요런 식으로...

# %% [markdown]
# `-` 중요한 설명변수 파악(빠르게 데이터를 파악하기에 용이...!)

# %%
auto.quick_fit(
    train_data = df_train,
    label = 'height',
    show_feature_importance_barplots = True  ## 설명변수 간 중요도를 간단히 시각화할 수 있음.
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231204_132955"
# ### Model Prediction for height
# Using validation data for `Test` points
# ### Model Leaderboard
#         model  score_test  score_val              eval_metric  pred_time_test  \
# 0  LightGBMXT   -3.441217  -3.881789  root_mean_squared_error        0.057294
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.002052  3.251215                 0.057294                0.002052
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           3.251215            1       True          1
# ### Feature Importance for Trained Model
#         importance    stddev       p_value  n   p99_high   p99_low
# weight    9.433162  0.468715  7.290537e-07  5  10.398253  8.468071
# sex       1.710680  0.464422  5.924364e-04  5   2.666932  0.754427
# ### Rows with the highest prediction error
# Rows in this category worth inspecting for the causes of the error
#         weight     sex      height  height_pred     error
# 208        NaN  female  159.027430   168.600342  9.572911
# 263  54.145913  female  165.791300   173.811340  8.020041
# 146  76.642564    male  175.011295   182.954391  7.943097
# 228  56.473758  female  165.962051   173.811340  7.849289
# 92   51.018586  female  160.851952   167.398270  6.546318
# 198        NaN    male  173.915293   180.355164  6.439870
# 157  46.214566  female  154.289882   160.576065  6.286183
# 106  69.667856    male  179.665916   173.611328  6.054588
# 118  48.711791  female  168.305739   162.763138  5.542602
# 166  77.068343    male  177.439194   182.954391  5.515197

# %% [markdown]
# > LightGBMXT로 빠르게 적합한 후, 잔차도와 설명변수 중요도를 추려준다. 잔차가 크거나 모호한 관측치를 나열해주기도 한다.

# %% [markdown]
# `-` 관측치 별 해석

# %% [markdown]
# * 0번 observation

# %%
df_train.iloc[[0]]
# Out:
#       weight   sex      height
# 0  71.169041  male  180.906857

# %%
predictr.predict(df_train.iloc[[0]])
# Out:
# 0    178.642868
# Name: height, dtype: float32

# %% [markdown]
# > 왜 해당 값으로 예측했어???

# %%
auto.explain_rows(
    train_data = df_train,
    model = predictr,
    rows = df_train.iloc[[0]],
    display_rows = True,
    plot = 'waterfall'
)
# Out:
#       weight   sex      height
# 0  71.169041  male  180.906857

# %% [markdown]
# > 일단은 평균값인 173.115에 적합
# >
# > `sex`를 고려하여 +2.1
# >
# > `weight`을 고려하여 +3.77
#
# 따라서 최종적으로 178.643.

# %% [markdown]
# * 208번 observation

# %%
df_train.iloc[[208]]
# Out:
#      weight     sex     height
# 208     NaN  female  159.02743

# %%
predictr.predict(df_train.iloc[[208]])
# Out:
# 208    168.788971
# Name: height, dtype: float32

# %% [markdown]
# > 어라? 결측치가 있는데 예측이 됐네?

# %%
auto.explain_rows(
    train_data = df_train,
    model = predictr,
    rows = df_train.iloc[[208]],
    display_rows = True,
    plot = 'waterfall'
)
# Out:
#      weight     sex     height
# 208     NaN  female  159.02743

# %% [markdown]
# > `NaN`값이 들어있음에도 평균으로 예측하는 것이 아닌 특정 값을 더해준다.
#
# **결측치를 하나의 관측치로 해석하여 적합**
#
# <span style="color:gray">트리에서 결측치인가? 아닌가?라는 노드가 존재한다고 보면 된다.</span>

# %% [markdown]
# ## 3. 이상치가 있는 데이터

# %% [markdown]
# ### **A. 데이터 EDA**
# ---

# %%
np.random.seed(43052)
temp = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/temp.csv').iloc[:100,3].to_numpy()
temp.sort()
ice_sales = 10 + temp * 0.5 + np.random.randn(100)
ice_sales[0] = 50
df_train = pd.DataFrame({'temp':temp,'ice_sales':ice_sales})
df_train
# Out:
#     temp  ice_sales
# 0   -4.1  50.000000
# 1   -3.7   9.234175
# 2   -3.0   9.642778
# 3   -1.3   9.657894
# 4   -0.5   9.987787
# ..   ...        ...
# 95  12.4  17.508688
# 96  13.4  17.105376
# 97  14.7  17.164930
# 98  15.0  18.555388
# 99  15.2  18.787014
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(df_train, x = 'temp', y = 'ice_sales', alpha = 0.8)
# Out:
# <Axes: xlabel='temp', ylabel='ice_sales'>

# %% [markdown]
# > 낮은 온도에서 이상치가 존재하는 데이터이다.

# %% [markdown]
# ### **B. 적합**
# ---

# %% [markdown]
# `-` 오늘도 정말 단순한 오토글루온 적합...

# %%
predictr = TabularPredictor(label = 'ice_sales')
predictr.fit(df_train)
yhat = predictr.predict(df_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231204_134323"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231204_134323"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #140-Ubuntu SMP Thu Aug 4 02:23:37 UTC 2022
# CPU Count:          128
# Memory Avail:       495.06 GB / 503.74 GB (98.3%)
# Disk Space Avail:   1421.49 GB / 1757.88 GB (80.9%)
# ===================================================
# Train Data Rows:    100
# Train Data Columns: 1
# Label Column:       ice_sales
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (50.0, 8.273155164108418, 13.17881, 4.33788)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    506941.99 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['temp']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['temp']
# 	0.0s = Fit runtime
# 	1 features in original data used to generate 1 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.02s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-2.2756	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-2.6883	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	-1.7039	 = Validation score   (-root_mean_squared_error)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-1.6843	 = Validation score   (-root_mean_squared_error)
# 	0.89s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-2.562	 = Validation score   (-root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-1.2192	 = Validation score   (-root_mean_squared_error)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-1.8631	 = Validation score   (-root_mean_squared_error)
# 	0.39s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-1.752	 = Validation score   (-root_mean_squared_error)
# 	1.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-1.3017	 = Validation score   (-root_mean_squared_error)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-1.1863	 = Validation score   (-root_mean_squared_error)
# 	1.06s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-2.0798	 = Validation score   (-root_mean_squared_error)
# 	1.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'NeuralNetTorch': 0.659, 'CatBoost': 0.227, 'LightGBM': 0.114}
# 	-1.1737	 = Validation score   (-root_mean_squared_error)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 6.49s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231204_134323")

# %%
sns.scatterplot(df_train, x = 'temp', y = 'ice_sales', alpha = 0.5)
sns.lineplot(df_train, x = 'temp', y = yhat)
# Out:
# <Axes: xlabel='temp', ylabel='ice_sales'>

# %% [markdown]
# > 잘 했네??

# %% [markdown]
# ### **C. 해석 및 시각화**
# ---

# %% [markdown]
# `-` y의 분포와 (X, y)의 관계 시각화

# %%
auto.target_analysis(
    train_data = df_train,
    label = 'ice_sales',
    fit_distributions = False
)
# Out:
# ## Target variable analysis
#            count       mean       std       min        25%        50%  \
# ice_sales    100  13.178805  4.337878  8.273155  11.296645  12.856589
#
#                  75%   max   dtypes  unique missing_count missing_ratio  \
# ice_sales  14.294614  50.0  float64     100
#
#           raw_type special_types
# ice_sales    float
# ### Target variable correlations
# **`train_data` - `spearman` correlation matrix; focus: absolute correlation for `ice_sales` >= `0.5`**
# **Feature interaction between `temp`/`ice_sales` in `train_data`**

# %% [markdown]
# `-` 중요한 설명변수...?

# %%
## auto.quick_fit()...? 설명변수가 하나예요...

# %% [markdown]
# * 설명변수가 하나이므로 생략한다.

# %% [markdown]
# `-` 관측치 별 해석

# %%
df_train.iloc[[0]]  ## 이상치!
# Out:
#    temp  ice_sales
# 0  -4.1       50.0

# %%
predictr.predict(df_train.iloc[[0]])
# Out:
# 0    18.292442
# Name: ice_sales, dtype: float32

# %%
auto.explain_rows(
    train_data = df_train,
    model = predictr,
    rows = df_train.iloc[[0]],
    display_rows = True,
    plot = 'waterfall'
)
# Out:
#    temp  ice_sales
# 0  -4.1       50.0

# %% [markdown]
# > 온도가 -4.1일 때 판매량의 평균치보다 그 값을 오히려 더해줬다.

# %% [markdown]
# ## 4. 쓸모없는 정보가 있을 때(오버피팅)

# %% [markdown]
# ### **A. 데이터**
# ---

# %%
np.random.randn(43052)
n_balance = 10 
toeic = np.random.randint(0,199,size=5000)*5
gpa = np.random.randint(100,450,size=5000)/100
u = toeic * 8/995 + gpa * 10/4.5
u = u - np.mean(u)
v = np.exp(u)/(1+np.exp(u))
employment = np.random.binomial(n=1,p=v)
df = pd.DataFrame({
'toiec':toeic,
'gpa':gpa,
'employment':employment
})
df_balance = pd.DataFrame((np.random.randn(5000,n_balance)).reshape(5000,n_balance)*1,columns = ['balance'+str(i) for i in range(n_balance)]) > 0
df = pd.concat([df,df_balance],axis=1).assign(employment = lambda df: df.employment.map({0:'No',1:'Yes'}))
df_train, df_test = sklearn.model_selection.train_test_split(df, test_size=0.7, random_state=42)

# %%
df_train
# Out:
#       toiec   gpa employment  balance0  balance1  balance2  balance3  \
# 4431    980  1.64        Yes      True     False      True      True
# 2162    155  2.29         No     False     False      True     False
# 2396    270  2.84         No     False     False      True     False
# 4768    250  4.46        Yes      True      True      True      True
# 2271    655  3.51        Yes     False      True      True      True
# ...     ...   ...        ...       ...       ...       ...       ...
# 4426    835  3.43        Yes     False     False     False     False
# 466     395  3.81        Yes     False      True     False     False
# 3092    810  2.80        Yes      True      True     False      True
# 3772    440  3.89        Yes      True      True     False      True
# 860     335  1.71         No      True     False     False     False
#
#       balance4  balance5  balance6  balance7  balance8  balance9
# 4431      True      True     False      True      True     False
# 2162     False     False     False     False      True      True
# 2396      True     False      True      True     False     False
# 4768     False     False     False     False     False     False
# 2271     False     False     False      True     False     False
# ...        ...       ...       ...       ...       ...       ...
# 4426      True      True      True     False     False     False
# 466       True     False      True     False     False      True
# 3092     False     False     False     False      True      True
# 3772      True      True      True      True      True     False
# 860      False     False     False     False      True     False
#
# [1500 rows x 13 columns]

# %% [markdown]
# ### **B. 적합**
# ---

# %%
## step 1 -- pass
## step 2 : create predictor
predictr = TabularPredictor(label = 'employment')
## step 3 : fitting
predictr.fit(df_train)
## step 4 : prediction
yhat = predictr.predict(df_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231204_140122"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231204_140122"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #140-Ubuntu SMP Thu Aug 4 02:23:37 UTC 2022
# CPU Count:          128
# Memory Avail:       495.00 GB / 503.74 GB (98.3%)
# Disk Space Avail:   1421.48 GB / 1757.88 GB (80.9%)
# ===================================================
# Train Data Rows:    1500
# Train Data Columns: 12
# Label Column:       employment
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['Yes', 'No']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    506884.40 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 10 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])  : 10 | ['balance0', 'balance1', 'balance2', 'balance3', 'balance4', ...]
# 		('float', []) :  1 | ['gpa']
# 		('int', [])   :  1 | ['toiec']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :  1 | ['gpa']
# 		('int', [])       :  1 | ['toiec']
# 		('int', ['bool']) : 10 | ['balance0', 'balance1', 'balance2', 'balance3', 'balance4', ...]
# 	0.1s = Fit runtime
# 	12 features in original data used to generate 12 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1200, Val Rows: 300
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.71	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.74	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.7967	 = Validation score   (accuracy)
# 	2.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.78	 = Validation score   (accuracy)
# 	1.92s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.7767	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.78	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.79	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7667	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.78	 = Validation score   (accuracy)
# 	0.5s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.7867	 = Validation score   (accuracy)
# 	3.14s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.7767	 = Validation score   (accuracy)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.8	 = Validation score   (accuracy)
# 	5.95s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.7767	 = Validation score   (accuracy)
# 	6.53s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMLarge': 0.435, 'LightGBM': 0.203, 'KNeighborsUnif': 0.13, 'NeuralNetTorch': 0.087, 'KNeighborsDist': 0.043, 'XGBoost': 0.043, 'CatBoost': 0.029, 'RandomForestEntr': 0.014, 'NeuralNetFastAI': 0.014}
# 	0.82	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 24.58s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231204_140122")

# %% [markdown]
# `AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).`
#
# > 알아서 분류 문제로 잘 인식하는 것을 알 수 있다.

# %% [markdown]
# ### **C. 해석 및 시각화**
# ---

# %% [markdown]
# `-` y의 분포, (X, y)의 관계

# %%
auto.target_analysis(
    train_data = df_train,
    label = 'employment',
    fit_distributions = False
)
# Out:
# ## Target variable analysis
#             count  unique top  freq  dtypes missing_count missing_ratio  \
# employment   1500       2  No   764  object
#
#            raw_type special_types
# employment   object
# ### Target variable correlations
# **`train_data` - `spearman` correlation matrix; focus: absolute correlation for `employment` >= `0.5`**
# **Feature interaction between `toiec`/`employment` in `train_data`**

# %% [markdown]
# > 마지막 히스토그램을 보면 토익 점수가 높아질수록 취업된 사람의 수가 많아짐을 알 수 있다. (낮을수록 취업 안된 사람도 많아지고 있음.)

# %% [markdown]
# `-` 중요한 설명변수

# %%
auto.quick_fit(
    train_data = df_train,
    label = 'employment',
    show_feature_importance_barplots = True
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231204_140944"
# ### Model Prediction for employment
# Using validation data for `Test` points
# ### Model Leaderboard
#         model  score_test  score_val eval_metric  pred_time_test  \
# 0  LightGBMXT    0.793333   0.852381    accuracy        0.001485
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.001719  1.904588                 0.001485                0.001719
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           1.904588            1       True          1
# ### Feature Importance for Trained Model
#           importance    stddev   p_value  n  p99_high   p99_low
# toiec       0.178222  0.024364  0.000041  5  0.228387  0.128057
# gpa         0.134667  0.022366  0.000088  5  0.180719  0.088614
# balance9    0.010667  0.003975  0.001941  5  0.018852  0.002482
# balance8    0.006222  0.002897  0.004318  5  0.012188  0.000256
# balance6    0.005333  0.006004  0.058977  5  0.017696 -0.007029
# balance0    0.004000  0.005963  0.104000  5  0.016278 -0.008278
# balance4    0.002222  0.004714  0.175651  5  0.011929 -0.007484
# balance2    0.000000  0.005212  0.500000  5  0.010731 -0.010731
# balance7   -0.000444  0.003975  0.592549  5  0.007741 -0.008630
# balance1   -0.001333  0.008255  0.631876  5  0.015664 -0.018331
# balance3   -0.001333  0.006004  0.677226  5  0.011029 -0.013696
# balance5   -0.007556  0.004869  0.987209  5  0.002469 -0.017580
# ### Rows with the highest prediction error
# Rows in this category worth inspecting for the causes of the error
#       toiec   gpa  balance0  balance1  balance2  balance3  balance4  balance5  \
# 4029    750  3.03     False      True      True     False      True     False
# 1975    295  1.34     False      True      True     False     False     False
# 4565    120  2.59      True     False      True     False      True     False
# 1021    655  3.41     False      True      True     False     False     False
# 3374     25  3.03     False      True     False     False     False      True
# 4775    850  2.85      True     False      True      True      True      True
# 3472    630  3.93     False      True     False      True      True      True
# 2243    765  2.56      True      True     False     False      True     False
# 4532    520  4.49      True      True      True      True     False     False
# 4132    700  3.63      True      True     False     False     False      True
#
#       balance6  balance7  balance8  balance9 employment        No       Yes  \
# 4029     False      True      True      True         No  0.032659  0.967341
# 1975     False      True      True      True        Yes  0.959335  0.040665
# 4565      True      True      True     False        Yes  0.954540  0.045460
# 1021      True     False     False      True         No  0.048881  0.951119
# 3374     False      True     False      True        Yes  0.949559  0.050441
# 4775     False      True      True      True         No  0.065697  0.934303
# 3472     False     False     False     False         No  0.067457  0.932543
# 2243     False      True     False      True         No  0.077888  0.922112
# 4532      True      True      True      True         No  0.082550  0.917450
# 4132      True     False      True     False         No  0.085991  0.914009
#
#          error
# 4029  0.934681
# 1975  0.918671
# 4565  0.909081
# 1021  0.902238
# 3374  0.899117
# 4775  0.868607
# 3472  0.865085
# 2243  0.844225
# 4532  0.834901
# 4132  0.828018
# ### Rows with the least distance vs other class
# Rows in this category are the closest to the decision boundary vs the other class and are good candidates for additional labeling
#       toiec   gpa  balance0  balance1  balance2  balance3  balance4  balance5  \
# 3847    280  3.27      True      True      True     False      True     False
# 428     550  2.23     False     False     False      True     False     False
# 2516    900  1.28     False      True     False     False     False     False
# 2549     80  4.24      True      True     False      True     False     False
# 2362    920  1.63      True     False      True     False     False     False
# 1458    700  2.23      True      True      True      True      True      True
# 2786    765  1.47     False      True      True     False     False      True
# 236     265  3.70     False      True     False     False      True      True
# 3777    230  4.37     False      True     False     False     False      True
# 4184    430  2.88      True     False      True      True      True     False
#
#       balance6  balance7  balance8  balance9 employment        No       Yes  \
# 3847     False      True     False     False         No  0.499199  0.500801
# 428      False      True     False     False         No  0.492622  0.507378
# 2516      True     False      True      True        Yes  0.511179  0.488821
# 2549      True     False      True     False        Yes  0.512349  0.487651
# 2362      True     False      True     False        Yes  0.514360  0.485640
# 1458     False     False      True     False        Yes  0.518368  0.481632
# 2786     False     False     False     False         No  0.480285  0.519715
# 236      False     False      True     False        Yes  0.521488  0.478512
# 3777      True      True     False      True        Yes  0.521911  0.478089
# 4184     False      True      True     False         No  0.474264  0.525736
#
#          error
# 3847  0.001601
# 428   0.014756
# 2516  0.022358
# 2549  0.024699
# 2362  0.028721
# 1458  0.036737
# 2786  0.039430
# 236   0.042975
# 3777  0.043823
# 4184  0.051473

# %% [markdown]
# > 토익과 gpa가 가장 중요하고, 쓸모없는 변수들의 중요도는 떨어지는 것을 파악할 수 있다.
# >
# > 분류하기 애매한 관측치(각 확률이 0.5에 가까움)가 따로 표기된다.

# %% [markdown]
# `-` 관측치 별 해석

# %% [markdown]
# * 0번 관측치

# %%
df_train.iloc[[0]]
# Out:
#       toiec   gpa employment  balance0  balance1  balance2  balance3  \
# 4431    980  1.64        Yes      True     False      True      True
#
#       balance4  balance5  balance6  balance7  balance8  balance9
# 4431      True      True     False      True      True     False

# %%
predictr.predict(df_train.iloc[[0]])  ## 여긴 왜 굳이 안곱해줘도 될까.
# Out:
# 4431    Yes
# Name: employment, dtype: object

# %%
auto.explain_rows(
    train_data = df_train,
    model = predictr,
    rows = df_train.iloc[[0]]*1,  ## 자료형이 bool로 들어가 있을 경우 1을 곱해줘야 한다.
    display_rows = True,
    plot = 'waterfall'
)
# Out:
#       toiec   gpa employment  balance0  balance1  balance2  balance3  \
# 4431    980  1.64        Yes         1         0         1         1
#
#       balance4  balance5  balance6  balance7  balance8  balance9
# 4431         1         1         0         1         1         0
