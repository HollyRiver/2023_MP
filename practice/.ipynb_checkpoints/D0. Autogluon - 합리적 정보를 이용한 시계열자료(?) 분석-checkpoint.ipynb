# %% [markdown]
# ---
# title: "`Autogluon`과 시계열 자료 분석 : 합리적 정보"
# author: "강신성"
# date: "2023-12-10"
# categories: [autogluon]
# ---

# %% [markdown]
# > 과거 관측치 이외의 요인을 포함한 시계열자료를 분석해보자.

# %% [markdown]
# ## 1. 라이브러리 imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.preprocessing
#---#}
from autogluon.tabular import TabularPredictor  ## 테뷸러데이터도 따로 적합?
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor
from autogluon.common import space
#---#
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. 데이터

# %% [markdown]
# ref : [kaggle competition](https://www.kaggle.com/competitions/bike-sharing-demand)

# %%
# !kaggle competitions download -c bike-sharing-demand
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading bike-sharing-demand.zip to /root/2023_MP/practice
# 100%|█████████████████████████████████████████| 189k/189k [00:00<00:00, 826kB/s]
# 100%|█████████████████████████████████████████| 189k/189k [00:00<00:00, 825kB/s]

# %%
# !unzip bike-sharing-demand.zip -d data
# Out:
# Archive:  bike-sharing-demand.zip
#   inflating: data/sampleSubmission.csv
#   inflating: data/test.csv
#   inflating: data/train.csv

# %%
sampleSubmission = pd.read_csv('data/sampleSubmission.csv')
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
# !rm -rf data
# !rm bike-sharing-demand.zip

# %% [markdown]
# `-` 자료 관찰

# %%
df_train
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'casual', 'count', 'registered'}

# %% [markdown]
# > 다른 부분이 세 개나 된다??

# %% [markdown]
# `-` 시계열 분석을 해야 하나?
#
# * 시간별로 정리된 시계열 자료이긴 하다.

# %%
display('train', df_train.iloc[::24][:20], 'test', df_test.iloc[:10])
# Out:
# 'train'
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 24   2011-01-02 00:00:00       1        0           0        2  18.86  22.725
# 48   2011-01-03 01:00:00       1        0           1        1   8.20   8.335
# 72   2011-01-04 04:00:00       1        0           1        1   5.74   9.090
# 96   2011-01-05 05:00:00       1        0           1        1   9.02  11.365
# 120  2011-01-06 06:00:00       1        0           1        2   5.74   8.335
# 144  2011-01-07 07:00:00       1        0           1        1   8.20  10.605
# 168  2011-01-08 07:00:00       1        0           0        2   6.56   9.090
# 192  2011-01-09 07:00:00       1        0           0        1   3.28   4.545
# 216  2011-01-10 07:00:00       1        0           1        1   4.92   6.060
# 240  2011-01-11 09:00:00       1        0           1        2   7.38   9.850
# 264  2011-01-12 11:00:00       1        0           1        1   8.20   9.090
# 288  2011-01-13 11:00:00       1        0           1        2   8.20   8.335
# 312  2011-01-14 12:00:00       1        0           1        1   8.20   9.850
# 336  2011-01-15 12:00:00       1        0           0        1   9.84  11.365
# 360  2011-01-16 12:00:00       1        0           0        1   9.84  10.605
# 384  2011-01-17 12:00:00       1        1           0        2   7.38   9.850
# 408  2011-01-19 00:00:00       1        0           1        2   9.02  13.635
# 432  2011-02-01 01:00:00       1        0           1        2   6.56   9.090
# 456  2011-02-02 02:00:00       1        0           1        3   9.02  11.365
#
#      humidity  windspeed  casual  registered  count
# 0          81     0.0000       3          13     16
# 24         88    19.9995       4          13     17
# 48         44    27.9993       0           2      2
# 72         63     6.0032       0           2      2
# 96         47    11.0014       0           3      3
# 120        63     7.0015       0          36     36
# 144        69     8.9981       8          76     84
# 168        74     7.0015       1           8      9
# 192        53    12.9980       1           5      6
# 216        50    15.0013       2          75     77
# 240        51    11.0014       3         127    130
# 264        51    26.0027       3          32     35
# 288        44    30.0026       4          33     37
# 312        44    16.9979       2          59     61
# 336        48    15.0013      15          74     89
# 360        41    19.0012      29          75    104
# 384        47     8.9981      10          70     80
# 408        93     0.0000       0           3      3
# 432        69     7.0015       0           3      3
# 456        93     8.9981       4           0      4
# 'test'
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5  2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6  2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7  2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8  2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9  2011-01-20 09:00:00       1        0           1        2   9.84  11.365
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014
# 5        60    15.0013
# 6        60    15.0013
# 7        55    15.0013
# 8        55    19.0012
# 9        52    15.0013

# %% [markdown]
# > `df_train`의 형태를 볼 때, 비어있는 시간이 있는 것을 알 수 있다. 즉, 테스트 데이터는 중간중간에서 추출되었다.(20일, 10일, 20일 10일 이런 식으로...)

# %% [markdown]
# `-` 데이터 분석 전략
#
# * 오히려 시계열을 피쳐엔지니어링하여 회귀문제로 바꾸는 게 적절하다.
# * 시계열 -> 요일, 시간의 피쳐 추출 + **외부자료**를 활용하여 휴일 유무 체크 + **외부자료**를 활용하여 해당 요일의 날씨 체크 -> 회귀문제로 해석!

# %% [markdown]
# ## 3. 적합

# %% [markdown]
# ### **A. 적합**
# ---

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'casual', 'count', 'registered'}

# %% [markdown]
# > 예측해야할 변수는 `count`에 해당함

# %% [markdown]
# `-` 데이터 전처리 : step 1

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()

df_train_featured = df_train_featured.drop(['casual', 'registered'], axis = 1)  ## 그냥 드롭해버림

# %% [markdown]
# `-` `predictor` 생성 및 적합, 예측

# %%
## step 2
predictr = TabularPredictor(label = 'count')

## step 3
predictr.fit(df_train_featured)

## step 4
yhat = predictr.predict(df_train_featured)
yyhat = predictr.predict(df_test_featured)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231210_083647"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231210_083647"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #140-Ubuntu SMP Thu Aug 4 02:23:37 UTC 2022
# CPU Count:          128
# Memory Avail:       382.90 GB / 503.74 GB (76.0%)
# Disk Space Avail:   1087.19 GB / 1757.88 GB (61.8%)
# ===================================================
# Train Data Rows:    10886
# Train Data Columns: 9
# Label Column:       count
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (977, 1, 191.57413, 181.14445)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    392090.82 MB
# 	Train Data (Original)  Memory Usage: 1.45 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                        : 5 | ['season', 'holiday', 'workingday', 'weather', 'humidity']
# 		('object', ['datetime_as_object']) : 1 | ['datetime']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 3 | ['season', 'weather', 'humidity']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.1s = Fit runtime
# 	9 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.93 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 9797, Val Rows: 1089
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-109.7394	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-92.4421	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 136.065
# 	-135.958	 = Validation score   (-root_mean_squared_error)
# 	7.72s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-134.0804	 = Validation score   (-root_mean_squared_error)
# 	4.98s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-122.0128	 = Validation score   (-root_mean_squared_error)
# 	0.7s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-134.2362	 = Validation score   (-root_mean_squared_error)
# 	6.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-128.4294	 = Validation score   (-root_mean_squared_error)
# 	0.53s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-136.5314	 = Validation score   (-root_mean_squared_error)
# 	24.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-135.0751	 = Validation score   (-root_mean_squared_error)
# 	1.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-139.9398	 = Validation score   (-root_mean_squared_error)
# 	47.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-132.1736	 = Validation score   (-root_mean_squared_error)
# 	10.42s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'KNeighborsDist': 1.0}
# 	-92.4421	 = Validation score   (-root_mean_squared_error)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 105.95s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231210_083647")

# %% [markdown]
# `-` 적합한 것을 관찰해보자.

# %%
plt.plot(df_train['count'][:300], '--', label = 'y')
plt.plot(yhat[:300], '--', label = 'yhat', alpha = 0.5, lw = 4)
plt.legend()

# %% [markdown]
# > 거의 동일하다. 이상하리만치 적합이 잘 되어있다. (왜 이렇게 잘맞춤???)

# %% [markdown]
# ### **B. 제출**
# ---

# %%
submission = sampleSubmission.copy()
submission
# Out:
#                  datetime  count
# 0     2011-01-20 00:00:00      0
# 1     2011-01-20 01:00:00      0
# 2     2011-01-20 02:00:00      0
# 3     2011-01-20 03:00:00      0
# 4     2011-01-20 04:00:00      0
# ...                   ...    ...
# 6488  2012-12-31 19:00:00      0
# 6489  2012-12-31 20:00:00      0
# 6490  2012-12-31 21:00:00      0
# 6491  2012-12-31 22:00:00      0
# 6492  2012-12-31 23:00:00      0
#
# [6493 rows x 2 columns]

# %%
submission['count'] = yyhat

# %%
submission.to_csv('submission.csv', index = False)
# !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "autogloun tabular predict"
# !rm submission.csv
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|████████████████████████████████████████| 188k/188k [00:02<00:00, 88.4kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# `-` 순위 확인...
#
# ![image.png](attachment:75a99478-4d51-4f56-8464-870f7c175868.png)

# %% [markdown]
# > 상당히 충격적인 결과, 냈다면 3171/3242등임...

# %% [markdown]
# `-` yyhat을 살펴보면...

# %%
plt.plot(yyhat[:300])
plt.plot(yhat[:300])

# %% [markdown]
# > `yhat`이랑 근본적으로 모양 자체가 다름...(요일이나 뭐 그런거나 다 신경쓰지 않고 뭉툭하게 적합하였음.)

# %% [markdown]
# ## 4. 적합 2

# %% [markdown]
# 불필요한 변수가 있거나, 공선성이 있거나, y와 완전히 관련된 변수가 따로 있나?

# %% [markdown]
# ### **A. 피쳐 엔지니어링**
# ---

# %% [markdown]
# `-` 일단 시계열로 적합할 생각이 없으므로, `datetime` 열은 삭제하는 게 좋겠음(인덱스 역할만 하는 쓸모없는 변수임)

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()
#----# 
df_train_featured = df_train_featured.drop(['casual','registered'],axis=1)
#--#
df_train_featured = df_train_featured.drop(['datetime'],axis=1)  ## 추가적으로 'datetime' 열을 제거하였음.
df_test_featured = df_test_featured.drop(['datetime'],axis=1)

# %% [markdown]
# ### **B. 적합**
# ---

# %% [markdown]
# `-` 동일하게 적합...

# %%
## step 2
predictr = TabularPredictor(label = 'count')

## step 3
predictr.fit(df_train_featured, verbosity = False)  ## 적합 과정을 말 많이 하지 말라고 하는 거

## step 4
yhat = predictr.predict(df_train_featured)
yyhat = predictr.predict(df_test_featured)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231210_100830"

# %% [markdown]
# `-` 적합결과 시각화

# %%
plt.plot(df_train['count'][:300], '--', label = 'y')
plt.plot(yhat[:300], '--', label = 'yhat', alpha = 0.5, lw = 4)
plt.legend()

# %% [markdown]
# > 너무 잘 적합되는 것을 벗어났다.(오히려 좋아.)

# %%
plt.plot(yyhat[:300], '--', alpha = 0.5, lw = 4, color = 'C1')

# %% [markdown]
# `-` 더 깔끔하고 예쁜 시각화(`seaborn`)

# %%
df = pd.concat([df_train, df_test]).assign(datetime = lambda _df : _df.datetime.apply(pd.to_datetime))\
.assign(count_hat = yhat.tolist() + yyhat.tolist(), dataset_type = ['train']*len(yhat) + ['test']*len(yyhat))

# %%
df.to_csv('df.csv', index = False)

# %% [markdown]
# > `test`와 `train`을 따로 시각화해버리면 시간이 연속되지 않아 이상함.

# %%
sns.lineplot(
    df.sort_values('datetime')[:(24*28)], ## 28일에 해당하는 자료만 시각화
    x = 'datetime', y = 'count',
    hue = 'dataset_type', linestyle = '--',
    lw = 0.8
)

sns.lineplot(
    df.sort_values('datetime')[:(24*28)],
    x = 'datetime', y = 'count_hat',
    hue = 'dataset_type',
    lw = 3, alpha = 0.5
)

fig = plt.gcf()
fig.set_size_inches(8,2)  ## 사이즈 조절
plt.xticks(rotation = 15);  ## x축 눈금 회전시키기

# %% [markdown]
# > 왜 `test` 데이터의 실제 관측치가 보이는 지는 모르겠지만(`matplotlib`에서는 결측치를 표기하지 않았었음...) 전보다는 나아보임.

# %%
def plotting(yhat, yyhat) :
    df = pd.concat([df_train, df_test]).assign(datetime = lambda _df : _df.datetime.apply(pd.to_datetime))\
.assign(count_hat = yhat.tolist() + yyhat.tolist(), dataset_type = ['train']*len(yhat) + ['test']*len(yyhat))
    sns.lineplot(
        df.sort_values('datetime')[:(24*28)], ## 28일에 해당하는 자료만 시각화
        x = 'datetime', y = 'count',
        hue = 'dataset_type', linestyle = '--',
        lw = 0.8
    )
    
    sns.lineplot(
        df.sort_values('datetime')[:(24*28)],
        x = 'datetime', y = 'count_hat',
        hue = 'dataset_type',
        lw = 3, alpha = 0.5
    )
    
    fig = plt.gcf()
    fig.set_size_inches(8,2)  ## 사이즈 조절
    plt.xticks(rotation = 15);  ## x축 눈금 회전시키기
    fig.show()

# %%
plotting(yhat, yyhat)

# %% [markdown]
# ### **C. 제출**
# ---

# %% [markdown]
# `-` 제출도 자동화...

# %%
submission['count'] == yyhat
submission.to_csv('submission.csv', index = False)
# !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "Message"
# !rm submission.csv
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|████████████████████████████████████████| 140k/140k [00:01<00:00, 72.6kB/s]
# Successfully submitted to Bike Sharing Demand

# %%
def submit(yyhat) :
    submission['count'] = yyhat
    submission.to_csv('submission.csv', index = False)
    # !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "Message"
    # !rm submission.csv

# %%
submit(0)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|████████████████████████████████████████| 140k/140k [00:01<00:00, 76.0kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# > 이게 된다.

# %% [markdown]
# ### **D. Pipeline Automation -- 싹 다 함수로 구현**
# ---

# %% [markdown]
# * 근데, 값이 음수라면 0이상이도록 정의해야 할 것 같음

# %%
submission['count'].apply(lambda x : x if x>0 else 0)  ## 음수일 경우 싹 다 0으로 바꿔서 표기, 중요한 테크닉
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6488    0
# 6489    0
# 6490    0
# 6491    0
# 6492    0
# Name: count, Length: 6493, dtype: int64

# %%
def submit(yyhat) :
    submission['count'] = yhat
    submission['count'] = submission['count'].apply(lambda x : x if x>0 else 0)
    submission.to_csv('submission.csv', index = False)
    # !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "Message"
    # !rm submission.csv

# %% [markdown]
# * 적합하는 코드

# %%
def fit_predict(df_train_featured, df_test_featured) :
    ## step 1 : pass -- 이미 정리된 데이터프레임을 넣어야 함
    ## step 2
    predictr = TabularPredictor(label = 'count', verbosity = False)
    ## step 3
    predictr.fit(df_train_featured)
    ## step 4
    yhat = predictr.predict(df_train_featured)
    yyhat = predictr.predict(df_test_featured)
    ## display
    display(predictr.leaderboard())
    return yhat, yyhat

# %% [markdown]
# * 위 두개를 엮어서 제출까지 한번에

# %%
def auto(df_train_featured, df_test_featured) :
    yhat, yyhat = fit_predict(df_train_featured, df_test_featured)
    plotting(yhat, yyhat)
    submit(yyhat)

# %%
auto(df_train_featured, df_test_featured)
# Out:
#                   model   score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2 -146.888192  root_mean_squared_error       0.367435
# 1              CatBoost -148.454154  root_mean_squared_error       0.002438
# 2       NeuralNetFastAI -148.826832  root_mean_squared_error       0.068091
# 3         LightGBMLarge -149.213280  root_mean_squared_error       0.081905
# 4            LightGBMXT -149.261116  root_mean_squared_error       0.083905
# 5               XGBoost -149.642096  root_mean_squared_error       0.003515
# 6              LightGBM -149.739171  root_mean_squared_error       0.087339
# 7        NeuralNetTorch -151.388293  root_mean_squared_error       0.008516
# 8         ExtraTreesMSE -156.627917  root_mean_squared_error       0.061404
# 9       RandomForestMSE -157.475877  root_mean_squared_error       0.060893
# 10       KNeighborsUnif -165.533975  root_mean_squared_error       0.055328
# 11       KNeighborsDist -176.146340  root_mean_squared_error       0.045405
#
#      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   82.157169                0.000284           0.212026            2
# 1    2.627903                0.002438           2.627903            1
# 2   24.261502                0.068091          24.261502            1
# 3    9.205640                0.081905           9.205640            1
# 4    6.809105                0.083905           6.809105            1
# 5    0.568598                0.003515           0.568598            1
# 6    2.417536                0.087339           2.417536            1
# 7   38.006247                0.008516          38.006247            1
# 8    0.497303                0.061404           0.497303            1
# 9    0.537443                0.060893           0.537443            1
# 10   0.011530                0.055328           0.011530            1
# 11   0.011765                0.045405           0.011765            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True          6
# 2        True          8
# 3        True         11
# 4        True          3
# 5        True          9
# 6        True          4
# 7        True         10
# 8        True          7
# 9        True          5
# 10       True          1
# 11       True          2
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|█████████████████████████████████████████| 243k/243k [00:02<00:00, 118kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# ## 5. 적합 3

# %% [markdown]
# ### **A. 시간 정보 피쳐엔지니어링**
# ---

# %% [markdown]
# * 시계열 자료에서 뽑아낼 수 있는 정보들을 추가적으로 넣어주고 싶다.

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()

df_train_featured = df_train_featured.drop(['casual', 'registered'], axis = 1)  ## 안겹치는 거 제거

df_train_featured.datetime = pd.to_datetime(df_train_featured.datetime)
df_test_featured.datetime = pd.to_datetime(df_test_featured.datetime)

## 시간 정보 매우 중요해보임
df_train_featured['hour'] = df_train_featured['datetime'].dt.hour
df_test_featured['hour'] = df_test_featured['datetime'].dt.hour

## 요일 정보도 중요해보임(추가적으로 공휴일 정보도 있으면 좋긴 함)
df_train_featured['weekday'] = df_train_featured['datetime'].dt.weekday
df_test_featured['weekday'] = df_test_featured['datetime'].dt.weekday

## 이제 쓸모없는 변수이니 드롭
df_train_featured = df_train_featured.drop(['datetime'], axis = 1)
df_test_featured = df_test_featured.drop('datetime', axis = 1)

# %% [markdown]
# ### **B. 적합, 시각화, 제출**
# ---

# %%
auto(df_train_featured, df_test_featured)
# Out:
#                   model   score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2  -59.163229  root_mean_squared_error       0.754458
# 1         LightGBMLarge  -60.899261  root_mean_squared_error       0.073212
# 2              CatBoost  -61.268467  root_mean_squared_error       0.003958
# 3              LightGBM  -61.447456  root_mean_squared_error       0.042291
# 4               XGBoost  -61.749260  root_mean_squared_error       0.005981
# 5            LightGBMXT  -62.400538  root_mean_squared_error       0.052641
# 6        NeuralNetTorch  -67.078156  root_mean_squared_error       0.576060
# 7       RandomForestMSE  -67.993149  root_mean_squared_error       0.061118
# 8         ExtraTreesMSE  -68.246627  root_mean_squared_error       0.062126
# 9       NeuralNetFastAI  -70.392342  root_mean_squared_error       0.140445
# 10       KNeighborsDist -115.023130  root_mean_squared_error       0.055920
# 11       KNeighborsUnif -117.802477  root_mean_squared_error       0.059005
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   737.895720                0.000315           0.213614            2
# 1    24.023241                0.073212          24.023241            1
# 2    55.502041                0.003958          55.502041            1
# 3    28.216985                0.042291          28.216985            1
# 4     1.124970                0.005981           1.124970            1
# 5    52.947245                0.052641          52.947245            1
# 6   575.867622                0.576060         575.867622            1
# 7     0.567920                0.061118           0.567920            1
# 8     0.572376                0.062126           0.572376            1
# 9   297.338515                0.140445         297.338515            1
# 10    0.013893                0.055920           0.013893            1
# 11    0.013270                0.059005           0.013270            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True         11
# 2        True          6
# 3        True          4
# 4        True          9
# 5        True          3
# 6        True         10
# 7        True          5
# 8        True          7
# 9        True          8
# 10       True          2
# 11       True          1
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|█████████████████████████████████████████| 243k/243k [00:02<00:00, 106kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# > 매우 좋은 결과...

# %% [markdown]
# ## 6. 추가적인 피쳐엔지니어링

# %% [markdown]
# ### **A. Step 1 : 관련없는 변수 삭제**
# ---

# %% [markdown]
# `-` 지금까지 수행했던 피쳐 엔지니어링

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()
#----# 
df_train_featured = df_train_featured.drop(['casual','registered'],axis=1)
#--#
df_train_featured['hour'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.hour
df_test_featured['hour'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.hour
df_train_featured['weekday'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.weekday
df_test_featured['weekday'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.weekday
#--#
df_train_featured = df_train_featured.drop(['datetime'],axis=1)
df_test_featured = df_test_featured.drop(['datetime'],axis=1)

# %% [markdown]
# `-` 변수 간 상관계수를 나타내는 히트맵 작성

# %%
sns.heatmap(df_train_featured.set_index('count').reset_index().corr(), vmin = -1, cmap = 'bwr')
## count를 인덱스로 넣고 리셋하여 count를 맨 위로 뺌
## vmin을 -1로 설정하여 상관계수 최소값을 명시(자신과의 상관이 1이기 때문에 max는 자동으로 1임)
## cmap을 blue, white, red로 선택하여 0에 가까울수록 하얗게 만들었다.
# Out:
# <Axes: >

# %% [markdown]
# > 어? `holiday`, `workingday`, `weekday`는 `count`와 관련이 없어보인다. $\to$ 제외하고 분석

# %%
auto(
    df_train_featured.drop(['holiday', 'workingday', 'weekday'], axis = 1),
    df_test_featured.drop(['holiday', 'workingday', 'weekday'], axis = 1)
)
# Out:
#                   model   score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2 -100.498646  root_mean_squared_error       0.547020
# 1              CatBoost -101.264453  root_mean_squared_error       0.002038
# 2            LightGBMXT -102.499627  root_mean_squared_error       0.088084
# 3         LightGBMLarge -102.767101  root_mean_squared_error       0.078442
# 4               XGBoost -103.481823  root_mean_squared_error       0.004044
# 5              LightGBM -103.565687  root_mean_squared_error       0.107222
# 6        NeuralNetTorch -105.320159  root_mean_squared_error       0.014690
# 7       NeuralNetFastAI -105.828124  root_mean_squared_error       0.387383
# 8       RandomForestMSE -106.378229  root_mean_squared_error       0.064174
# 9         ExtraTreesMSE -106.730503  root_mean_squared_error       0.061677
# 10       KNeighborsUnif -128.806002  root_mean_squared_error       0.063364
# 11       KNeighborsDist -128.946333  root_mean_squared_error       0.059375
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   660.666850                0.000293           0.212799            2
# 1     3.918867                0.002038           3.918867            1
# 2    10.506166                0.088084          10.506166            1
# 3    11.698817                0.078442          11.698817            1
# 4     0.605335                0.004044           0.605335            1
# 5     5.513531                0.107222           5.513531            1
# 6   346.275792                0.014690         346.275792            1
# 7   297.933651                0.387383         297.933651            1
# 8     0.626922                0.064174           0.626922            1
# 9     0.516230                0.061677           0.516230            1
# 10    0.012975                0.063364           0.012975            1
# 11    0.012877                0.059375           0.012877            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True          6
# 2        True          3
# 3        True         11
# 4        True          9
# 5        True          4
# 6        True         10
# 7        True          8
# 8        True          5
# 9        True          7
# 10       True          1
# 11       True          2
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|█████████████████████████████████████████| 243k/243k [00:02<00:00, 122kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# > 오히려 더 안좋아짐...
#
# `-` **왜 이런 결과가 나오는가??**

# %%
sex =  np.array([0,0,0,0]*100+[0] + [1]+[1,1,1,1]*100 + [2]*401)
surv = np.array([0,0,0,0]*100+[1] + [0]+[1,1,1,1]*100 + [0]*401) 
surv_conti = surv + np.random.randn(len(surv))*0.1
_df = pd.DataFrame({'sex':sex, 'surv':surv, 'surv_conti':surv_conti})
_df.corr()
# Out:
#                 sex      surv  surv_conti
# sex         1.00000 -0.002160    0.006710
# surv       -0.00216  1.000000    0.978614
# surv_conti  0.00671  0.978614    1.000000

# %%
sns.heatmap(_df.corr(), vmin = -1, cmap = 'bwr')
# Out:
# <Axes: >

# %%
sns.scatterplot(_df, x = 'sex', y = 'surv_conti', alpha = 0.5)

# %% [markdown]
# 성별에 따라 생존 여부가 크게 차이가 나는 것 같은데 상관계수는 0이다...??
#
# > 범주형 자료로 나타나는 자료간 상관계수는 해석에 유의해야 한다. (성별이 0, 1, 2가 있으면 2일 때 가장 높다...??? $\to$ 이상함)

# %% [markdown]
# `-` 분석 자료에 해당 방법을 적용해보자...

# %% [markdown]
# * `holiday`는 유효한가??

# %%
sns.scatterplot(
    df_train_featured,
    x = 'holiday',
    y = 'count',
    alpha = 0.1
)
# Out:
# <Axes: xlabel='holiday', ylabel='count'>

# %% [markdown]
# > 유의할 정도의 차이는 있다. 휴일일 때의 표본이 좀 더 적어서 상관계수가 낮게 나온 것도 있다.

# %% [markdown]
# * `weekday`는 유효한가??

# %%
sns.scatterplot(
    df_train_featured,
    x = 'weekday',
    y = 'count',
    alpha = 0.1
)
# Out:
# <Axes: xlabel='weekday', ylabel='count'>

# %% [markdown]
# > 이것도 상관계수가 거의 0이 나올 것, 하지만 분명 의미있는 변수임.

# %% [markdown]
# * `workingday`(영업일)은 유의한가?

# %%
sns.scatterplot(
    df_train_featured,
    x = 'workingday',
    y = 'count',
    alpha = 0.1
)
# Out:
# <Axes: xlabel='workingday', ylabel='count'>

# %% [markdown]
# > 이것도 근무하는 날이 더 많이 빌리는 것 같음...

# %% [markdown]
# * 연속형의 경우 악의적으로 꼬기 어렵기 때문에 상관계수를 봐도 됨.
# * 범주형의 경우... 원리를 생각해봐야 함.

# %% [markdown]
# ### **B. Step2 - (다중공선성 열) atemp 혹은 temp 삭제**
# ---

# %% [markdown]
# `-` 지금까지 한 피쳐엔지니어링

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()
#----# 
df_train_featured = df_train_featured.drop(['casual','registered'],axis=1)
#--#
df_train_featured['hour'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.hour
df_test_featured['hour'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.hour
df_train_featured['weekday'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.weekday
df_test_featured['weekday'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.weekday
#--#
df_train_featured = df_train_featured.drop(['datetime'],axis=1)
df_test_featured = df_test_featured.drop(['datetime'],axis=1)

# %%
sns.heatmap(df_train_featured.set_index('count').reset_index().corr(), vmin = -1, cmap = 'bwr')
# Out:
# <Axes: >

# %% [markdown]
# > `temp`와 `atemp`와의 상관계수가 그냥 1에 가깝다. 그냥 똑같은 변수 같음.

# %%
sns.scatterplot(df_train_featured, x = 'temp', y = 'atemp', alpha = 0.2)
# Out:
# <Axes: xlabel='temp', ylabel='atemp'>

# %% [markdown]
# > 둘 다 동시에 있을 경우 공선성 문제를 만들 수 있어 보인다. 따라서 둘 중 하나를 제거하는 것이 좋을 것 같음.

# %%
## 둘 다 적합해보고 더 좋았던 것을 택하면 됨...
auto(
    df_train_featured.drop(['atemp'], axis = 1),
    df_test_featured.drop(['atemp'], axis = 1)
)
# Out:
#                   model   score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2  -59.241125  root_mean_squared_error       0.290179
# 1         LightGBMLarge  -60.667457  root_mean_squared_error       0.033918
# 2              CatBoost  -60.919338  root_mean_squared_error       0.005002
# 3            LightGBMXT  -61.740606  root_mean_squared_error       0.098863
# 4              LightGBM  -62.028032  root_mean_squared_error       0.079755
# 5               XGBoost  -62.503591  root_mean_squared_error       0.005199
# 6        NeuralNetTorch  -67.658734  root_mean_squared_error       0.072342
# 7       RandomForestMSE  -67.814371  root_mean_squared_error       0.077016
# 8         ExtraTreesMSE  -67.843089  root_mean_squared_error       0.060838
# 9       NeuralNetFastAI  -72.297034  root_mean_squared_error       0.074487
# 10       KNeighborsDist -112.678494  root_mean_squared_error       0.050523
# 11       KNeighborsUnif -115.103505  root_mean_squared_error       0.053975
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   275.395760                0.000300           0.209980            2
# 1    19.198702                0.033918          19.198702            1
# 2    23.853067                0.005002          23.853067            1
# 3    37.499263                0.098863          37.499263            1
# 4    31.093493                0.079755          31.093493            1
# 5     1.042938                0.005199           1.042938            1
# 6   163.541256                0.072342         163.541256            1
# 7     0.660360                0.077016           0.660360            1
# 8     0.548458                0.060838           0.548458            1
# 9    23.098105                0.074487          23.098105            1
# 10    0.013834                0.050523           0.013834            1
# 11    0.013111                0.053975           0.013111            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True         11
# 2        True          6
# 3        True          3
# 4        True          4
# 5        True          9
# 6        True         10
# 7        True          5
# 8        True          7
# 9        True          8
# 10       True          2
# 11       True          1
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|█████████████████████████████████████████| 243k/243k [00:02<00:00, 114kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# > `atemp`를 제거하는 것이 더 좋았다.

# %% [markdown]
# ### **C. Step 3 : season을 범주로...?**
# ---

# %% [markdown]
# `-` 지금까지 한 피쳐엔지니어링...

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()
#----# 
df_train_featured = df_train_featured.drop(['casual','registered'],axis=1)
#--#
df_train_featured['hour'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.hour
df_test_featured['hour'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.hour
df_train_featured['weekday'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.weekday
df_test_featured['weekday'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.weekday
#--#
df_train_featured = df_train_featured.drop(['datetime'],axis=1)
df_test_featured = df_test_featured.drop(['datetime'],axis=1)
#--#
df_train_featured = df_train_featured.drop(['atemp'],axis=1)  ## atemp 제거 추가
df_test_featured = df_test_featured.drop(['atemp'],axis=1)

# %% [markdown]
# `-` `season` 열의 의미는 봄-여름-가을-겨울 순서대로 1,2,3,4이다.
#
# >  이렇게 하면 더미변수가 아닌 연속형 자료로 해석하게 될 텐데, 문자열로 바꾸면 더 좋지 않을까?

# %%
auto(
    df_train_featured.assign(season = df_train_featured.season.map({1:'spring', 2:'summer',3:'fall', 4:'winter'})),
    df_test_featured.assign(season = df_test_featured.season.map({1:'spring', 2:'summer',3:'fall', 4:'winter'}))
)
# Out:
#                   model   score_val              eval_metric  pred_time_val  \
# 0   WeightedEnsemble_L2  -58.622011  root_mean_squared_error       0.186801
# 1            LightGBMXT  -61.072683  root_mean_squared_error       0.126509
# 2         LightGBMLarge  -61.188052  root_mean_squared_error       0.032841
# 3              CatBoost  -62.040378  root_mean_squared_error       0.007358
# 4              LightGBM  -62.161719  root_mean_squared_error       0.063699
# 5               XGBoost  -62.183089  root_mean_squared_error       0.008106
# 6        NeuralNetTorch  -65.967056  root_mean_squared_error       0.011701
# 7       RandomForestMSE  -68.346914  root_mean_squared_error       0.061778
# 8         ExtraTreesMSE  -68.569688  root_mean_squared_error       0.061246
# 9       NeuralNetFastAI  -71.912011  root_mean_squared_error       0.017022
# 10       KNeighborsDist -113.647125  root_mean_squared_error       0.054443
# 11       KNeighborsUnif -116.110797  root_mean_squared_error       0.059873
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   407.208220                0.000285           0.209064            2
# 1    58.820569                0.126509          58.820569            1
# 2    26.792214                0.032841          26.792214            1
# 3    99.755842                0.007358          99.755842            1
# 4    15.457030                0.063699          15.457030            1
# 5     1.411524                0.008106           1.411524            1
# 6   220.219006                0.011701         220.219006            1
# 7     0.571033                0.061778           0.571033            1
# 8     0.537777                0.061246           0.537777            1
# 9    25.430087                0.017022          25.430087            1
# 10    0.012470                0.054443           0.012470            1
# 11    0.011844                0.059873           0.011844            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True          3
# 2        True         11
# 3        True          6
# 4        True          4
# 5        True          9
# 6        True         10
# 7        True          5
# 8        True          7
# 9        True          8
# 10       True          2
# 11       True          1
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|█████████████████████████████████████████| 188k/188k [00:01<00:00, 103kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# * 이건 적용하지 않는 게 더 좋았다.
# * 리더보드에 있는 모형은 다 트리 계열인데... **어차피 트리계열은 명목형 변수를 순서형 변수로 잘못 적용하더라도 큰 차이 없음**(차피 구간으로 나누니까...)

# %% [markdown]
# ### **D. Step 4 : $y$의 분포**
# ---

# %% [markdown]
# `-` 지금까지 한 피쳐엔지니어링(계절 범주화는 안했음)

# %%
df_train_featured = df_train.copy()
df_test_featured = df_test.copy()
#----# 
df_train_featured = df_train_featured.drop(['casual','registered'],axis=1)
#--#
df_train_featured['hour'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.hour
df_test_featured['hour'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.hour
df_train_featured['weekday'] = df_train_featured['datetime'].apply(pd.to_datetime).dt.weekday
df_test_featured['weekday'] = df_test_featured['datetime'].apply(pd.to_datetime).dt.weekday
#--#
df_train_featured = df_train_featured.drop(['datetime'],axis=1)
df_test_featured = df_test_featured.drop(['datetime'],axis=1)
#--#
df_train_featured = df_train_featured.drop(['atemp'],axis=1)
df_test_featured = df_test_featured.drop(['atemp'],axis=1)

# %% [markdown]
# `-` $y$에 어떤 특정한 분포가 적용되지 않을까?

# %%
df_train_featured['count'].hist()
# Out:
# <Axes: >

# %% [markdown]
# > $y$(자전거 대여 수)가 정규분포는 아니네(`count`가 낮은 쪽에 많이 있음)

# %% [markdown]
# `-` `count`를 변환하여 적합하고, 역변환하자!

# %% [markdown]
# * 변환(로그변환)

# %%
transfomr = sklearn.preprocessing.PowerTransformer(method = 'box-cox')  ## 박스콕스 변환!(y값이 클수록 눌러줌)

# %%
count2 = transfomr.fit_transform(df_train_featured[['count']]).reshape(-1)
plt.hist(count2);

# %% [markdown]
# * 적합

# %%
## step 1 : pass
## step 2
predictr = TabularPredictor(label = 'count')

## step 3
predictr.fit(df_train_featured.assign(count = count2))  ## 변환한 값 할당

## step 4
yhat = predictr.predict(df_train_featured.assign(count = count2))  ## 마찬가지로 변환한 값을...
yyhat = predictr.predict(df_test_featured)

yhat = transfomr.inverse_transform(yhat.to_frame()).reshape(-1)  ## 역변환, 예상 시 나온 값이 시리즈 형태이므로 데이터프레임 폼으로 바꿔줘야 함
yyhat = transfomr.inverse_transform(yyhat.to_frame()).reshape(-1)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231210_123742"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231210_123742"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #140-Ubuntu SMP Thu Aug 4 02:23:37 UTC 2022
# CPU Count:          128
# Memory Avail:       385.33 GB / 503.74 GB (76.5%)
# Disk Space Avail:   1060.49 GB / 1757.88 GB (60.3%)
# ===================================================
# Train Data Rows:    10886
# Train Data Columns: 9
# Label Column:       count
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (2.3448179251161907, -2.043720466219865, -0.0, 1.00005)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    394651.88 MB
# 	Train Data (Original)  Memory Usage: 0.66 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['temp', 'windspeed']
# 		('int', [])   : 7 | ['season', 'holiday', 'workingday', 'weather', 'humidity', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 2 | ['temp', 'windspeed']
# 		('int', [])       : 5 | ['season', 'weather', 'humidity', 'hour', 'weekday']
# 		('int', ['bool']) : 2 | ['holiday', 'workingday']
# 	0.0s = Fit runtime
# 	9 features in original data used to generate 9 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.52 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 9797, Val Rows: 1089
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.5323	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.5163	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 0.271595
# [2000]	valid_set's rmse: 0.264936
# [3000]	valid_set's rmse: 0.26348
# 	-0.2634	 = Validation score   (-root_mean_squared_error)
# 	29.07s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 0.265909
# [2000]	valid_set's rmse: 0.263351
# [3000]	valid_set's rmse: 0.262316
# 	-0.2622	 = Validation score   (-root_mean_squared_error)
# 	18.7s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-0.2928	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-0.2537	 = Validation score   (-root_mean_squared_error)
# 	22.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-0.2878	 = Validation score   (-root_mean_squared_error)
# 	0.52s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-0.2972	 = Validation score   (-root_mean_squared_error)
# 	21.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-0.2592	 = Validation score   (-root_mean_squared_error)
# 	1.18s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-0.3006	 = Validation score   (-root_mean_squared_error)
# 	76.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's rmse: 0.256542
# 	-0.2558	 = Validation score   (-root_mean_squared_error)
# 	18.8s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'CatBoost': 0.372, 'LightGBMLarge': 0.346, 'LightGBMXT': 0.179, 'XGBoost': 0.103}
# 	-0.25	 = Validation score   (-root_mean_squared_error)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 190.18s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231210_123742")

# %%
plotting(yhat, yyhat)

# %%
submit(yyhat)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|████████████████████████████████████████| 188k/188k [00:02<00:00, 88.6kB/s]
# Successfully submitted to Bike Sharing Demand

# %% [markdown]
# > 고작 변환만 했을 뿐인데, 모형이 엄청나게 개선된 것을 알 수 있다. 고작 변환만 했을 뿐인데!!
